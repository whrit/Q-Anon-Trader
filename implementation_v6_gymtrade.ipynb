# %%
import time
import pickle
import numpy as np
from src.environment import StockTradingEnvironment
from src.utils import save_pickle, load_pickle, plot_grid
from src.learner import q_learning_learning_loop
import yfinance as yf
import random
import matplotlib.pyplot as plt
from collections import deque
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.optimizers import Adam
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.callbacks import LearningRateScheduler
import logging
import multiprocessing as mp
import cProfile
import pstats
import atexit

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    device = '/GPU:0'
    logging.info("Using GPU for training")
else:
    device = '/CPU:0'
    logging.info("Using CPU for training")
# Out:
# 2024-06-24 14:33:49,569 - INFO - Using GPU for training

# %%
def fetch_stock_data(symbol, start_date, end_date, output_file):
    stock_data = yf.download(symbol, start=start_date, end=end_date)
    stock_data['Close'] = stock_data['Adj Close']
    
    stock_data = stock_data.drop(columns=['Adj Close'])

    # Convert column headers to lowercase
    stock_data.columns = stock_data.columns.str.lower()

    stock_data.to_csv(output_file)
        
    return stock_data

stock_data = fetch_stock_data('AAPL', '2019-06-20', '2024-06-21', 'AAPL_data.csv')

# %%
def huber_loss(y_true, y_pred, clip_delta=1.0):
    """Huber loss - Custom Loss Function for Q Learning

    Links: 	https://en.wikipedia.org/wiki/Huber_loss
            https://jaromiru.com/2017/05/27/on-using-huber-loss-in-deep-q-learning/
    """
    error = y_true - y_pred
    cond = K.abs(error) <= clip_delta
    squared_loss = 0.5 * K.square(error)
    quadratic_loss = 0.5 * K.square(clip_delta) + clip_delta * (K.abs(error) - clip_delta)
    return K.mean(tf.where(cond, squared_loss, quadratic_loss))

# %% [markdown]
# #### Q-Learning

# %%
class SumTree:
    def __init__(self, capacity):
        self.capacity = capacity
        self.tree = np.zeros(2 * capacity - 1)
        self.data = np.zeros(capacity, dtype=object)
        self.write = 0

    def _propagate(self, idx, change):
        parent = (idx - 1) // 2
        self.tree[parent] += change
        if parent != 0:
            self._propagate(parent, change)

    def _retrieve(self, idx, s):
        left = 2 * idx + 1
        right = left + 1
        if left >= len(self.tree):
            return idx
        if s <= self.tree[left]:
            return self._retrieve(left, s)
        else:
            return self._retrieve(right, s - self.tree[left])

    def total(self):
        return self.tree[0]

    def add(self, p, data):
        idx = self.write + self.capacity - 1
        self.data[self.write] = data
        self.update(idx, p)
        self.write += 1
        if self.write >= self.capacity:
            self.write = 0

    def update(self, idx, p):
        change = p - self.tree[idx]
        self.tree[idx] = p
        self._propagate(idx, change)

    def get(self, s):
        idx = self._retrieve(0, s)
        dataIdx = idx - self.capacity + 1
        return idx, self.tree[idx], self.data[dataIdx]

class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha=0.6):
        self.tree = SumTree(capacity)
        self.alpha = alpha
        self.capacity = capacity
        self.epsilon = 0.01

    def add(self, error, sample):
        p = (error + self.epsilon) ** self.alpha
        self.tree.add(p, sample)

    def sample(self, batch_size, beta=0.4):
        batch = []
        idxs = []
        segment = self.tree.total() / batch_size
        priorities = []
        for i in range(batch_size):
            a = segment * i
            b = segment * (i + 1)
            s = random.uniform(a, b)
            idx, p, data = self.tree.get(s)
            batch.append(data)
            idxs.append(idx)
            priorities.append(p)
        sampling_probabilities = priorities / self.tree.total()
        is_weights = np.power(self.tree.capacity * sampling_probabilities, -beta)
        is_weights /= is_weights.max()
        return batch, idxs, is_weights

    def update(self, idx, error):
        p = (error + self.epsilon) ** self.alpha
        self.tree.update(idx, p)

# %%
class DoubleQLearningAgent:
    def __init__(self, env, learning_rate, discount_factor, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995):
        self.env = env
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.q_table1 = {}
        self.q_table2 = {}

    def step(self, state):
        state_index = self._get_state_index(state)
        if np.random.rand() < self.epsilon:
            return np.random.choice(self.env.action_space.n)
        else:
            q_values = self.q_table1.get(state_index, np.zeros(self.env.action_space.n)) + self.q_table2.get(state_index, np.zeros(self.env.action_space.n))
            return np.argmax(q_values)

    def update_qvalue(self, state, action, reward, next_state):
        state_index = self._get_state_index(state)
        next_state_index = self._get_state_index(next_state)
        if np.random.rand() < 0.5:
            best_next_action = np.argmax(self.q_table1.get(next_state_index, np.zeros(self.env.action_space.n)))
            self.q_table1[state_index] = self.q_table1.get(state_index, np.zeros(self.env.action_space.n))
            self.q_table1[state_index][action] += self.learning_rate * (
                reward + self.discount_factor * self.q_table2.get(next_state_index, np.zeros(self.env.action_space.n))[best_next_action] - self.q_table1[state_index][action]
            )
        else:
            best_next_action = np.argmax(self.q_table2.get(next_state_index, np.zeros(self.env.action_space.n)))
            self.q_table2[state_index] = self.q_table2.get(state_index, np.zeros(self.env.action_space.n))
            self.q_table2[state_index][action] += self.learning_rate * (
                reward + self.discount_factor * self.q_table1.get(next_state_index, np.zeros(self.env.action_space.n))[best_next_action] - self.q_table2[state_index][action]
            )

    def _get_state_index(self, state):
        return tuple(state.flatten())

    def decay_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

class DQNAgent:
    def __init__(self, env, model_name='DQN_model', gamma=0.95, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995, learning_rate=0.001):
        self.env = env
        self.model_name = model_name
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.learning_rate = learning_rate
        self.loss = self.huber_loss
        self.custom_objects = {"huber_loss": self.huber_loss}
        self.optimizer = Adam(lr=self.learning_rate)
        self.buffer_size = 10000
        self.batch_size = 32
        self.memory = PrioritizedReplayBuffer(self.buffer_size, 0.6)
        self.beta = 0.4
        self.model = self.build_model()
        self.target_model = self.build_model()
        self.update_target_model()

    def build_model(self):
        model = Sequential()
        model.add(Dense(units=128, activation="relu", input_dim=self.env.observation_space.shape[0]))
        model.add(Dense(units=256, activation="relu"))
        model.add(Dense(units=256, activation="relu"))
        model.add(Dense(units=128, activation="relu"))
        model.add(Dense(units=self.env.action_space.n))
        model.compile(loss=self.loss, optimizer=self.optimizer)
        return model

    def huber_loss(self, y_true, y_pred):
        error = y_true - y_pred
        return tf.where(tf.abs(error) < 1.0, 0.5 * tf.square(error), tf.abs(error) - 0.5)

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    def remember(self, state, action, reward, next_state, done):
        state = state.flatten().reshape(1, -1)
        next_state = next_state.flatten().reshape(1, -1)
        target = reward + self.gamma * np.amax(self.target_model.predict(next_state)[0]) if not done else reward
        td_error = abs(target - np.amax(self.model.predict(state)[0]))
        self.memory.add(td_error, (state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(self.env.action_space.n)
        state = state.flatten().reshape(1, -1)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self):
        if len(self.memory.tree.data) < self.batch_size:
            return
        minibatch, idxs, is_weights = self.memory.sample(self.batch_size, self.beta)
        states, actions, rewards, next_states, dones = zip(*minibatch)
        states = np.array(states).reshape(self.batch_size, -1)
        next_states = np.array(next_states).reshape(self.batch_size, -1)
        targets = self.model.predict(states)
        targets_next = self.target_model.predict(next_states)

        for i in range(self.batch_size):
            target = rewards[i] + self.gamma * np.amax(targets_next[i]) if not dones[i] else rewards[i]
            td_error = abs(target - targets[i][actions[i]])
            self.memory.update(idxs[i], td_error)
            targets[i][actions[i]] = target

        self.model.fit(states, targets, epochs=1, verbose=0)
        self.update_target_model()

    def decay_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
def collect_experience(env, agent, epsilon):
    obs, _ = env.reset()
    terminated, truncated = False, False
    experiences = []

    while not terminated and not truncated:
        current_action = agent.step(obs)
        next_obs, reward, terminated, truncated, _ = env.step(current_action)
        experiences.append((obs, current_action, reward, next_obs, terminated))
        obs = next_obs

    return experiences

def adaptive_learning_rate(epoch, lr):
    if epoch % 100 == 0 and epoch:
        return lr * 0.1
    return lr

def decay_epsilon(episode, epsilon, min_epsilon, decay_rate):
    return max(min_epsilon, epsilon * decay_rate)

def q_learning_learning_loop(env, agent, learning_rate: float, discount_factor: float, episodes: int,
                             min_epsilon_allowed: float, initial_epsilon_value: float,
                             buffer_size: int = 10000, batch_size: int = 32, decay_method="exponential") -> tuple:
    epsilon = initial_epsilon_value
    epsilon_decay_factor = np.power(min_epsilon_allowed / epsilon, 1 / episodes)

    reward_across_episodes = []
    epsilons_across_episodes = []

    replay_buffer = deque(maxlen=buffer_size)

    for episode in range(episodes):
        experiences = collect_experience(env, agent, epsilon)
        replay_buffer.extend(experiences)

        if len(replay_buffer) >= batch_size:
            batch = np.array(random.sample(replay_buffer, batch_size), dtype=object)
            for b_state, b_action, b_reward, b_next_state, b_done in batch:
                b_state = tuple(b_state.flatten())
                b_next_state = tuple(b_next_state.flatten())
                if b_done:
                    target = b_reward
                else:
                    target = b_reward + discount_factor * np.max(agent.q_table1.get(b_next_state, np.zeros(env.action_space.n)) + agent.q_table2.get(b_next_state, np.zeros(env.action_space.n)))

                agent.q_table1[b_state] = agent.q_table1.get(b_state, np.zeros(env.action_space.n))
                agent.q_table1[b_state][b_action] += learning_rate * (target - agent.q_table1[b_state][b_action])

        if decay_method == "exponential":
            epsilon = decay_epsilon(episode, epsilon, min_epsilon_allowed, epsilon_decay_factor)
        else:
            epsilon = max(min_epsilon_allowed, epsilon - (initial_epsilon_value - min_epsilon_allowed) / episodes)

        reward_across_episodes.append(sum([exp[2] for exp in experiences]))
        epsilons_across_episodes.append(epsilon)

        agent.decay_epsilon()  # Apply epsilon decay after each episode

        if (episode + 1) % 100 == 0:
            logging.info(f"Episode {episode + 1}/{episodes} - Reward: {reward_across_episodes[-1]} - Epsilon: {epsilon}")

    logging.info("Trained Q-Table: %s", agent.q_table1)

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(reward_across_episodes, label='Rewards')
    plt.xlabel('Episodes')
    plt.ylabel('Cumulative Reward')
    plt.title('Rewards over Episodes')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epsilons_across_episodes, label='Epsilon')
    plt.xlabel('Episodes')
    plt.ylabel('Epsilon')
    plt.title('Epsilon Decay over Episodes')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    return agent, reward_across_episodes, epsilons_across_episodes

# %%
def parallel_collect_experience(env, agent, epsilon, num_workers=8):
    with mp.Pool(num_workers) as pool:
        results = pool.starmap(collect_experience, [(env, agent, epsilon) for _ in range(num_workers)])
    experiences = [exp for result in results for exp in result]
    return experiences

# %%
# NOTE: You can adjust the parameter 'number_of_days_to_consider'

# env = stock_trading_environment = StockTradingEnvironment('./AAPL_data.csv', number_of_days_to_consider=30)

# %%
def train_agent():
    env = stock_trading_environment = StockTradingEnvironment('./AAPL_data.csv', number_of_days_to_consider=20)

    agent = DoubleQLearningAgent(env, learning_rate=0.001, discount_factor=0.95)

    agent, reward_across_episodes, epsilons_across_episodes = q_learning_learning_loop(
        env,
        agent,
        learning_rate=0.001,
        discount_factor=0.95,
        episodes=25000,
        min_epsilon_allowed=0.01,
        initial_epsilon_value=1,
        buffer_size=100000,
        batch_size=128,
        decay_method="exponential"
    )

    return env, agent, reward_across_episodes, epsilons_across_episodes, stock_trading_environment

# %%
def run_learned_policy(env, agent):
    obs, _ = env.reset()
    terminated, truncated = False, False
    total_reward = 0
    steps = 0

    while not terminated and not truncated:
        obs_tuple = tuple(obs.flatten())
        action = np.argmax(agent.q_table1.get(obs_tuple, np.zeros(env.action_space.n)) + agent.q_table2.get(obs_tuple, np.zeros(env.action_space.n)))
        obs, reward, terminated, truncated, _ = env.step(action)
        total_reward += reward
        steps += 1

    logging.info("Total Reward: %d, Steps: %d", total_reward, steps)
    return total_reward

# %%
if __name__ == "__main__":
    profiler = cProfile.Profile()
    profiler.enable()

    try:
        env, agent, reward_across_episodes, epsilons_across_episodes = train_agent()
    finally:
        profiler.disable()
        profiler.dump_stats('training_profile.prof')
        
        with open('profile_results.txt', 'w') as f:
            stats = pstats.Stats('training_profile.prof', stream=f)
            stats.sort_stats('cumulative').print_stats(20)
        
        atexit.register(profiler.disable) 

    total_reward = run_learned_policy(env, agent)
# Out:
# /Users/beckett/miniconda3/envs/tradeEnv/lib/python3.10/site-packages/ta/trend.py:1030: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self._psar[i] = high2
# Columns after adding technical indicators: Index(['open', 'high', 'low', 'close', 'volume', 'volume_adi', 'volume_obv',
#        'volume_cmf', 'volume_fi', 'volume_em', 'volume_sma_em', 'volume_vpt',
#        'volume_vwap', 'volume_mfi', 'volume_nvi', 'volatility_bbm',
#        'volatility_bbh', 'volatility_bbl', 'volatility_bbw', 'volatility_bbp',
#        'volatility_bbhi', 'volatility_bbli', 'volatility_kcc',
#        'volatility_kch', 'volatility_kcl', 'volatility_kcw', 'volatility_kcp',
#        'volatility_kchi', 'volatility_kcli', 'volatility_dcl',
#        'volatility_dch', 'volatility_dcm', 'volatility_dcw', 'volatility_dcp',
#        'volatility_atr', 'volatility_ui', 'trend_macd', 'trend_macd_signal',
#        'trend_macd_diff', 'trend_sma_fast', 'trend_sma_slow', 'trend_ema_fast',
#        'trend_ema_slow', 'trend_vortex_ind_pos', 'trend_vortex_ind_neg',
#        'trend_vortex_ind_diff', 'trend_trix', 'trend_mass_index', 'trend_dpo',
#        'trend_kst', 'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_conv',
#        'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b',
#        'trend_stc', 'trend_adx', 'trend_adx_pos', 'trend_adx_neg', 'trend_cci',
#        'trend_visual_ichimoku_a', 'trend_visual_ichimoku_b', 'trend_aroon_up',
#        'trend_aroon_down', 'trend_aroon_ind', 'trend_psar_up',
#        'trend_psar_down', 'trend_psar_up_indicator',
#        'trend_psar_down_indicator', 'momentum_rsi', 'momentum_stoch_rsi',
#        'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_tsi',
#        'momentum_uo', 'momentum_stoch', 'momentum_stoch_signal', 'momentum_wr',
#        'momentum_ao', 'momentum_roc', 'momentum_ppo', 'momentum_ppo_signal',
#        'momentum_ppo_hist', 'momentum_pvo', 'momentum_pvo_signal',
#        'momentum_pvo_hist', 'momentum_kama', 'others_dr', 'others_dlr',
#        'others_cr'],
#       dtype='object')
# Market Return : 335.70%   |   Portfolio Return : 133.57%   |
# Market Return : 335.70%   |   Portfolio Return : -48.63%   |
# Market Return : 335.70%   |   Portfolio Return : -33.78%   |
# Market Return : 335.70%   |   Portfolio Return : 22.76%   |
# Market Return : 335.70%   |   Portfolio Return : -50.51%   |
# Market Return : 335.70%   |   Portfolio Return : -24.06%   |
# Market Return : 335.70%   |   Portfolio Return : -64.37%   |
# Market Return : 335.70%   |   Portfolio Return : -65.00%   |
# Market Return : 335.70%   |   Portfolio Return : -39.49%   |
# Market Return : 335.70%   |   Portfolio Return : -64.55%   |
# Market Return : 335.70%   |   Portfolio Return : -19.49%   |
# Market Return : 335.70%   |   Portfolio Return : -29.30%   |
# Market Return : 335.70%   |   Portfolio Return : -24.82%   |
# Market Return : 335.70%   |   Portfolio Return : -76.76%   |
# Market Return : 335.70%   |   Portfolio Return : 53.11%   |
# Market Return : 335.70%   |   Portfolio Return : -4.92%   |
# Market Return : 335.70%   |   Portfolio Return : -57.19%   |
# Market Return : 335.70%   |   Portfolio Return : 204.68%   |
# Market Return : 335.70%   |   Portfolio Return : -69.21%   |
# Market Return : 335.70%   |   Portfolio Return : 18.68%   |
# Market Return : 335.70%   |   Portfolio Return : 42.96%   |
# Market Return : 335.70%   |   Portfolio Return : 26.50%   |
# Market Return : 335.70%   |   Portfolio Return : -23.83%   |
# Market Return : 335.70%   |   Portfolio Return : -6.40%   |
# Market Return : 335.70%   |   Portfolio Return : -10.01%   |
# Market Return : 335.70%   |   Portfolio Return : -70.10%   |
# Market Return : 335.70%   |   Portfolio Return : -25.31%   |
# Market Return : 335.70%   |   Portfolio Return : -56.74%   |
# Market Return : 335.70%   |   Portfolio Return : 49.98%   |
# Market Return : 335.70%   |   Portfolio Return : -3.75%   |
# Market Return : 335.70%   |   Portfolio Return : 131.41%   |
# Market Return : 335.70%   |   Portfolio Return : 108.05%   |
# Market Return : 335.70%   |   Portfolio Return : 55.09%   |
# Market Return : 335.70%   |   Portfolio Return : -42.23%   |
# Market Return : 335.70%   |   Portfolio Return : 44.51%   |
# Market Return : 335.70%   |   Portfolio Return : -32.82%   |
# Market Return : 335.70%   |   Portfolio Return : -13.11%   |
# Market Return : 335.70%   |   Portfolio Return : -3.96%   |
# Market Return : 335.70%   |   Portfolio Return : 42.14%   |
# Market Return : 335.70%   |   Portfolio Return : 110.17%   |
# Market Return : 335.70%   |   Portfolio Return : 274.48%   |
# Market Return : 335.70%   |   Portfolio Return : 42.19%   |
# Market Return : 335.70%   |   Portfolio Return : 20.66%   |
# Market Return : 335.70%   |   Portfolio Return : 40.42%   |
# Market Return : 335.70%   |   Portfolio Return :  7.31%   |
# Market Return : 335.70%   |   Portfolio Return : 20.25%   |
# Market Return : 335.70%   |   Portfolio Return : -11.18%   |
# Market Return : 335.70%   |   Portfolio Return : 59.34%   |
# Market Return : 335.70%   |   Portfolio Return : 19.23%   |
# Market Return : 335.70%   |   Portfolio Return : 24.37%   |
# Market Return : 335.70%   |   Portfolio Return : 32.66%   |
# Market Return : 335.70%   |   Portfolio Return : 182.20%   |
# Market Return : 335.70%   |   Portfolio Return :  4.69%   |
# Market Return : 335.70%   |   Portfolio Return : 112.42%   |
# Market Return : 335.70%   |   Portfolio Return : -25.13%   |
# Market Return : 335.70%   |   Portfolio Return : 17.50%   |
# Market Return : 335.70%   |   Portfolio Return : 15.97%   |
# Market Return : 335.70%   |   Portfolio Return : 62.12%   |
# Market Return : 335.70%   |   Portfolio Return :  2.64%   |
# Market Return : 335.70%   |   Portfolio Return : 46.24%   |
# Market Return : 335.70%   |   Portfolio Return : 199.82%   |
# Market Return : 335.70%   |   Portfolio Return : 27.37%   |
# Market Return : 335.70%   |   Portfolio Return : 65.55%   |
# Market Return : 335.70%   |   Portfolio Return : -1.18%   |
# Market Return : 335.70%   |   Portfolio Return : -40.70%   |
# Market Return : 335.70%   |   Portfolio Return :  3.29%   |
# Market Return : 335.70%   |   Portfolio Return : 341.50%   |
# Market Return : 335.70%   |   Portfolio Return : 322.87%   |
# Market Return : 335.70%   |   Portfolio Return : 149.19%   |
# Market Return : 335.70%   |   Portfolio Return : 20.91%   |
# Market Return : 335.70%   |   Portfolio Return : -13.12%   |
# Market Return : 335.70%   |   Portfolio Return : 54.64%   |
# Market Return : 335.70%   |   Portfolio Return :  0.39%   |
# Market Return : 335.70%   |   Portfolio Return : 71.49%   |
# Market Return : 335.70%   |   Portfolio Return : 174.80%   |
# Market Return : 335.70%   |   Portfolio Return : 96.81%   |
# Market Return : 335.70%   |   Portfolio Return : 259.11%   |
# Market Return : 335.70%   |   Portfolio Return : 309.01%   |
# Market Return : 335.70%   |   Portfolio Return : 68.26%   |
# Market Return : 335.70%   |   Portfolio Return : -12.38%   |
# Market Return : 335.70%   |   Portfolio Return : 55.98%   |
# Market Return : 335.70%   |   Portfolio Return :  5.45%   |
# Market Return : 335.70%   |   Portfolio Return : 30.23%   |
# Market Return : 335.70%   |   Portfolio Return : 20.79%   |
# Market Return : 335.70%   |   Portfolio Return : 135.37%   |
# Market Return : 335.70%   |   Portfolio Return : 297.77%   |
# Market Return : 335.70%   |   Portfolio Return : 318.03%   |
# Market Return : 335.70%   |   Portfolio Return : 40.30%   |
# Market Return : 335.70%   |   Portfolio Return : -41.58%   |
# Market Return : 335.70%   |   Portfolio Return : 399.24%   |
# Market Return : 335.70%   |   Portfolio Return : 76.56%   |
# Market Return : 335.70%   |   Portfolio Return : 128.35%   |
# Market Return : 335.70%   |   Portfolio Return : -36.27%   |
# Market Return : 335.70%   |   Portfolio Return : 90.36%   |
# Market Return : 335.70%   |   Portfolio Return : 335.33%   |
# Market Return : 335.70%   |   Portfolio Return :  4.19%   |
# Market Return : 335.70%   |   Portfolio Return : 116.82%   |
# Market Return : 335.70%   |   Portfolio Return : 253.60%   |
# 2024-06-24 14:34:19,474 - INFO - Episode 100/25000 - Reward: 1.4284663867460345 - Epsilon: 0.9817479430199813
# Market Return : 335.70%   |   Portfolio Return : 256.56%   |
# Market Return : 335.70%   |   Portfolio Return : 317.23%   |
# Market Return : 335.70%   |   Portfolio Return : 865.99%   |
# Market Return : 335.70%   |   Portfolio Return : 140.54%   |
# Market Return : 335.70%   |   Portfolio Return : 103.57%   |
# Market Return : 335.70%   |   Portfolio Return : 267.70%   |
# Market Return : 335.70%   |   Portfolio Return : 49.54%   |
# Market Return : 335.70%   |   Portfolio Return : 410.59%   |
# Market Return : 335.70%   |   Portfolio Return : 61.37%   |
# Market Return : 335.70%   |   Portfolio Return : 216.12%   |
# Market Return : 335.70%   |   Portfolio Return : 71.01%   |
# Market Return : 335.70%   |   Portfolio Return : 130.03%   |
# Market Return : 335.70%   |   Portfolio Return : 168.96%   |
# Market Return : 335.70%   |   Portfolio Return : 367.81%   |
# Market Return : 335.70%   |   Portfolio Return : 52.49%   |
# Market Return : 335.70%   |   Portfolio Return : 148.87%   |
# Market Return : 335.70%   |   Portfolio Return : 386.22%   |
# Market Return : 335.70%   |   Portfolio Return : 190.71%   |
# Market Return : 335.70%   |   Portfolio Return : 53.80%   |
# Market Return : 335.70%   |   Portfolio Return : 371.70%   |
# Market Return : 335.70%   |   Portfolio Return : 498.80%   |
# Market Return : 335.70%   |   Portfolio Return : 542.70%   |
# Market Return : 335.70%   |   Portfolio Return : 255.26%   |
# Market Return : 335.70%   |   Portfolio Return : 350.75%   |
# Market Return : 335.70%   |   Portfolio Return : 179.84%   |
# Market Return : 335.70%   |   Portfolio Return : 525.57%   |
# Market Return : 335.70%   |   Portfolio Return : 154.20%   |
# Market Return : 335.70%   |   Portfolio Return : 214.94%   |
# Market Return : 335.70%   |   Portfolio Return : 127.89%   |
# Market Return : 335.70%   |   Portfolio Return : 410.20%   |
# Market Return : 335.70%   |   Portfolio Return : 155.03%   |
# Market Return : 335.70%   |   Portfolio Return : 223.52%   |
# Market Return : 335.70%   |   Portfolio Return : 550.75%   |
# Market Return : 335.70%   |   Portfolio Return : 410.22%   |
# Market Return : 335.70%   |   Portfolio Return : 862.54%   |
# Market Return : 335.70%   |   Portfolio Return : 119.95%   |
# Market Return : 335.70%   |   Portfolio Return : 326.20%   |
# Market Return : 335.70%   |   Portfolio Return : 288.95%   |
# Market Return : 335.70%   |   Portfolio Return : 923.55%   |
# Market Return : 335.70%   |   Portfolio Return : 382.46%   |
# Market Return : 335.70%   |   Portfolio Return : 196.84%   |
# Market Return : 335.70%   |   Portfolio Return : 85.89%   |
# Market Return : 335.70%   |   Portfolio Return : 44.66%   |
# Market Return : 335.70%   |   Portfolio Return : 625.05%   |
# Market Return : 335.70%   |   Portfolio Return : 528.61%   |
# Market Return : 335.70%   |   Portfolio Return : 246.21%   |
# Market Return : 335.70%   |   Portfolio Return : 645.20%   |
# Market Return : 335.70%   |   Portfolio Return : 765.85%   |
# Market Return : 335.70%   |   Portfolio Return : 327.76%   |
# Market Return : 335.70%   |   Portfolio Return : 301.31%   |
# Market Return : 335.70%   |   Portfolio Return : 587.96%   |
# Market Return : 335.70%   |   Portfolio Return : 355.12%   |
# Market Return : 335.70%   |   Portfolio Return : 340.08%   |
# Market Return : 335.70%   |   Portfolio Return : 709.95%   |
# Market Return : 335.70%   |   Portfolio Return : 1142.45%   |
# Market Return : 335.70%   |   Portfolio Return : 1702.35%   |
# Market Return : 335.70%   |   Portfolio Return : 85.82%   |
# Market Return : 335.70%   |   Portfolio Return : 759.90%   |
# Market Return : 335.70%   |   Portfolio Return : 713.41%   |
# Market Return : 335.70%   |   Portfolio Return : 328.34%   |
# Market Return : 335.70%   |   Portfolio Return : 543.35%   |
# Market Return : 335.70%   |   Portfolio Return : 303.50%   |
# Market Return : 335.70%   |   Portfolio Return : 291.67%   |
# Market Return : 335.70%   |   Portfolio Return : 542.97%   |
# Market Return : 335.70%   |   Portfolio Return : 111.30%   |
# Market Return : 335.70%   |   Portfolio Return : 217.05%   |
# Market Return : 335.70%   |   Portfolio Return : 248.83%   |
# Market Return : 335.70%   |   Portfolio Return : 672.14%   |
# Market Return : 335.70%   |   Portfolio Return : 308.36%   |
# Market Return : 335.70%   |   Portfolio Return : 1374.62%   |
# Market Return : 335.70%   |   Portfolio Return : 199.28%   |
# Market Return : 335.70%   |   Portfolio Return : 409.92%   |
# Market Return : 335.70%   |   Portfolio Return : 389.48%   |
# Market Return : 335.70%   |   Portfolio Return : 1140.10%   |
# Market Return : 335.70%   |   Portfolio Return : 571.37%   |
# Market Return : 335.70%   |   Portfolio Return : 965.75%   |
# Market Return : 335.70%   |   Portfolio Return : 656.00%   |
# Market Return : 335.70%   |   Portfolio Return : 964.48%   |
# Market Return : 335.70%   |   Portfolio Return : 782.43%   |
# Market Return : 335.70%   |   Portfolio Return : 715.95%   |
# Market Return : 335.70%   |   Portfolio Return : 194.66%   |
# Market Return : 335.70%   |   Portfolio Return : 549.84%   |
# Market Return : 335.70%   |   Portfolio Return : 367.42%   |
# Market Return : 335.70%   |   Portfolio Return : 417.65%   |
# Market Return : 335.70%   |   Portfolio Return : 186.63%   |
# Market Return : 335.70%   |   Portfolio Return : 354.07%   |
# Market Return : 335.70%   |   Portfolio Return : 769.31%   |
# Market Return : 335.70%   |   Portfolio Return : 1131.21%   |
# Market Return : 335.70%   |   Portfolio Return : 780.33%   |
# Market Return : 335.70%   |   Portfolio Return : 325.01%   |
# Market Return : 335.70%   |   Portfolio Return : 394.26%   |
# Market Return : 335.70%   |   Portfolio Return : 456.57%   |
# Market Return : 335.70%   |   Portfolio Return : 129.25%   |
# Market Return : 335.70%   |   Portfolio Return : 398.14%   |
# Market Return : 335.70%   |   Portfolio Return : 725.08%   |
# Market Return : 335.70%   |   Portfolio Return : 646.11%   |
# Market Return : 335.70%   |   Portfolio Return : 146.29%   |
# Market Return : 335.70%   |   Portfolio Return : 404.47%   |
# Market Return : 335.70%   |   Portfolio Return : 506.15%   |
# Market Return : 335.70%   |   Portfolio Return : 343.91%   |
# 2024-06-24 14:34:25,432 - INFO - Episode 200/25000 - Reward: 1.4029079738046204 - Epsilon: 0.9638290236239637
# Market Return : 335.70%   |   Portfolio Return : 347.22%   |
# Market Return : 335.70%   |   Portfolio Return : 306.70%   |
# Market Return : 335.70%   |   Portfolio Return : 188.76%   |
# Market Return : 335.70%   |   Portfolio Return : 1590.79%   |
# Market Return : 335.70%   |   Portfolio Return : 328.64%   |
# Market Return : 335.70%   |   Portfolio Return : 450.85%   |
# Market Return : 335.70%   |   Portfolio Return : 714.21%   |
# Market Return : 335.70%   |   Portfolio Return : 903.93%   |
# Market Return : 335.70%   |   Portfolio Return : 330.24%   |
# Market Return : 335.70%   |   Portfolio Return : 906.65%   |
# Market Return : 335.70%   |   Portfolio Return : 146.26%   |
# Market Return : 335.70%   |   Portfolio Return : 219.68%   |
# Market Return : 335.70%   |   Portfolio Return : 223.78%   |
# Market Return : 335.70%   |   Portfolio Return : 626.77%   |
# Market Return : 335.70%   |   Portfolio Return : 473.99%   |
# Market Return : 335.70%   |   Portfolio Return : 217.68%   |
# Market Return : 335.70%   |   Portfolio Return : 55.33%   |
# Market Return : 335.70%   |   Portfolio Return : 189.09%   |
# Market Return : 335.70%   |   Portfolio Return : 159.43%   |
# Market Return : 335.70%   |   Portfolio Return : 94.98%   |
# Market Return : 335.70%   |   Portfolio Return : 668.84%   |
# Market Return : 335.70%   |   Portfolio Return : 660.37%   |
# Market Return : 335.70%   |   Portfolio Return : 839.77%   |
# Market Return : 335.70%   |   Portfolio Return : 979.71%   |
# Market Return : 335.70%   |   Portfolio Return : 913.58%   |
# Market Return : 335.70%   |   Portfolio Return : 327.30%   |
# Market Return : 335.70%   |   Portfolio Return : 1644.48%   |
# Market Return : 335.70%   |   Portfolio Return : 1097.32%   |
# Market Return : 335.70%   |   Portfolio Return : 982.86%   |
# Market Return : 335.70%   |   Portfolio Return : 593.11%   |
# Market Return : 335.70%   |   Portfolio Return : 804.33%   |
# Market Return : 335.70%   |   Portfolio Return : 170.61%   |
# Market Return : 335.70%   |   Portfolio Return : 666.33%   |
# Market Return : 335.70%   |   Portfolio Return : 1770.38%   |
# Market Return : 335.70%   |   Portfolio Return : 142.84%   |
# Market Return : 335.70%   |   Portfolio Return : 1438.32%   |
# Market Return : 335.70%   |   Portfolio Return : 544.45%   |
# Market Return : 335.70%   |   Portfolio Return : 164.95%   |
# Market Return : 335.70%   |   Portfolio Return : 429.21%   |
# Market Return : 335.70%   |   Portfolio Return : 962.59%   |
# Market Return : 335.70%   |   Portfolio Return : 360.75%   |
# Market Return : 335.70%   |   Portfolio Return : 1197.60%   |
# Market Return : 335.70%   |   Portfolio Return : 401.67%   |
# Market Return : 335.70%   |   Portfolio Return : 534.62%   |
# Market Return : 335.70%   |   Portfolio Return : 520.22%   |
# Market Return : 335.70%   |   Portfolio Return : 234.72%   |
# Market Return : 335.70%   |   Portfolio Return : 717.45%   |
# Market Return : 335.70%   |   Portfolio Return : 1040.10%   |
# Market Return : 335.70%   |   Portfolio Return : 891.37%   |
# Market Return : 335.70%   |   Portfolio Return : 574.32%   |
# Market Return : 335.70%   |   Portfolio Return : 462.74%   |
# Market Return : 335.70%   |   Portfolio Return : 1372.48%   |
# Market Return : 335.70%   |   Portfolio Return : 541.06%   |
# Market Return : 335.70%   |   Portfolio Return : 367.43%   |
# Market Return : 335.70%   |   Portfolio Return : 1818.91%   |
# Market Return : 335.70%   |   Portfolio Return : 645.10%   |
# Market Return : 335.70%   |   Portfolio Return : 328.40%   |
# Market Return : 335.70%   |   Portfolio Return : 406.99%   |
# Market Return : 335.70%   |   Portfolio Return : 656.55%   |
# Market Return : 335.70%   |   Portfolio Return : 1097.23%   |
# Market Return : 335.70%   |   Portfolio Return : 209.36%   |
# Market Return : 335.70%   |   Portfolio Return : 346.45%   |
# Market Return : 335.70%   |   Portfolio Return : 713.35%   |
# Market Return : 335.70%   |   Portfolio Return : 409.55%   |
# Market Return : 335.70%   |   Portfolio Return : 441.91%   |
# Market Return : 335.70%   |   Portfolio Return : 778.81%   |
# Market Return : 335.70%   |   Portfolio Return : 947.96%   |
# Market Return : 335.70%   |   Portfolio Return : 1305.38%   |
# Market Return : 335.70%   |   Portfolio Return : 945.51%   |
# Market Return : 335.70%   |   Portfolio Return : 1023.54%   |
# Market Return : 335.70%   |   Portfolio Return : 398.07%   |
# Market Return : 335.70%   |   Portfolio Return : 394.62%   |
# Market Return : 335.70%   |   Portfolio Return : 619.34%   |
# Market Return : 335.70%   |   Portfolio Return : 776.04%   |
# Market Return : 335.70%   |   Portfolio Return : 1913.66%   |
# Market Return : 335.70%   |   Portfolio Return : 1184.68%   |
# Market Return : 335.70%   |   Portfolio Return : 949.14%   |
# Market Return : 335.70%   |   Portfolio Return : 1050.02%   |
# Market Return : 335.70%   |   Portfolio Return : 639.64%   |
# Market Return : 335.70%   |   Portfolio Return : 422.95%   |
# Market Return : 335.70%   |   Portfolio Return : 1346.18%   |
# Market Return : 335.70%   |   Portfolio Return : 255.92%   |
# Market Return : 335.70%   |   Portfolio Return : 991.47%   |
# Market Return : 335.70%   |   Portfolio Return : 1427.54%   |
# Market Return : 335.70%   |   Portfolio Return : 1627.25%   |
# Market Return : 335.70%   |   Portfolio Return : 389.59%   |
# Market Return : 335.70%   |   Portfolio Return : 306.94%   |
# Market Return : 335.70%   |   Portfolio Return : 1181.79%   |
# Market Return : 335.70%   |   Portfolio Return : 821.27%   |
# Market Return : 335.70%   |   Portfolio Return : 291.16%   |
# Market Return : 335.70%   |   Portfolio Return : 543.38%   |
# Market Return : 335.70%   |   Portfolio Return : 1586.29%   |
# Market Return : 335.70%   |   Portfolio Return : 1144.77%   |
# Market Return : 335.70%   |   Portfolio Return : 340.82%   |
# Market Return : 335.70%   |   Portfolio Return : 844.67%   |
# Market Return : 335.70%   |   Portfolio Return : 409.10%   |
# 2024-06-24 14:34:31,259 - INFO - Episode 300/25000 - Reward: 1.5409506773136685 - Epsilon: 0.9462371613657831
# Market Return : 335.70%   |   Portfolio Return : 809.69%   |
# Market Return : 335.70%   |   Portfolio Return : 2173.93%   |
# Market Return : 335.70%   |   Portfolio Return : 744.85%   |
# Market Return : 335.70%   |   Portfolio Return : 494.91%   |
# Market Return : 335.70%   |   Portfolio Return : 392.12%   |
# Market Return : 335.70%   |   Portfolio Return : 366.90%   |
# Market Return : 335.70%   |   Portfolio Return : 1112.32%   |
# Market Return : 335.70%   |   Portfolio Return : 617.12%   |
# Market Return : 335.70%   |   Portfolio Return : 676.27%   |
# Market Return : 335.70%   |   Portfolio Return : 1575.56%   |
# Market Return : 335.70%   |   Portfolio Return : 649.39%   |
# Market Return : 335.70%   |   Portfolio Return : 381.16%   |
# Market Return : 335.70%   |   Portfolio Return : 503.83%   |
# Market Return : 335.70%   |   Portfolio Return : 521.24%   |
# Market Return : 335.70%   |   Portfolio Return : 1482.15%   |
# Market Return : 335.70%   |   Portfolio Return : 1436.97%   |
# Market Return : 335.70%   |   Portfolio Return : 1041.85%   |
# Market Return : 335.70%   |   Portfolio Return : 1798.42%   |
# Market Return : 335.70%   |   Portfolio Return : 2845.22%   |
# Market Return : 335.70%   |   Portfolio Return : 288.74%   |
# Market Return : 335.70%   |   Portfolio Return : 440.25%   |
# Market Return : 335.70%   |   Portfolio Return : 841.82%   |
# Market Return : 335.70%   |   Portfolio Return : 277.17%   |
# Market Return : 335.70%   |   Portfolio Return : 786.08%   |
# Market Return : 335.70%   |   Portfolio Return : 681.20%   |
# Market Return : 335.70%   |   Portfolio Return : 613.50%   |
# Market Return : 335.70%   |   Portfolio Return : 369.99%   |
# Market Return : 335.70%   |   Portfolio Return : 1456.36%   |
# Market Return : 335.70%   |   Portfolio Return : 393.66%   |
# Market Return : 335.70%   |   Portfolio Return : 329.19%   |
# Market Return : 335.70%   |   Portfolio Return : 459.57%   |
# Market Return : 335.70%   |   Portfolio Return : 216.81%   |
# Market Return : 335.70%   |   Portfolio Return : 1039.55%   |
# Market Return : 335.70%   |   Portfolio Return : 211.21%   |
# Market Return : 335.70%   |   Portfolio Return : 693.46%   |
# Market Return : 335.70%   |   Portfolio Return : 385.67%   |
# Market Return : 335.70%   |   Portfolio Return : 201.96%   |
# Market Return : 335.70%   |   Portfolio Return : 1879.14%   |
# Market Return : 335.70%   |   Portfolio Return : 750.19%   |
# Market Return : 335.70%   |   Portfolio Return : 1656.02%   |
# Market Return : 335.70%   |   Portfolio Return : 1074.46%   |
# Market Return : 335.70%   |   Portfolio Return : 1389.72%   |
# Market Return : 335.70%   |   Portfolio Return : 886.37%   |
# Market Return : 335.70%   |   Portfolio Return : 180.61%   |
# Market Return : 335.70%   |   Portfolio Return : 813.55%   |
# Market Return : 335.70%   |   Portfolio Return : 606.76%   |
# Market Return : 335.70%   |   Portfolio Return : 1079.92%   |
# Market Return : 335.70%   |   Portfolio Return : 228.61%   |
# Market Return : 335.70%   |   Portfolio Return : 484.36%   |
# Market Return : 335.70%   |   Portfolio Return : 293.42%   |
# Market Return : 335.70%   |   Portfolio Return : 577.67%   |
# Market Return : 335.70%   |   Portfolio Return : 459.37%   |
# Market Return : 335.70%   |   Portfolio Return : 1140.23%   |
# Market Return : 335.70%   |   Portfolio Return : 427.58%   |
# Market Return : 335.70%   |   Portfolio Return : 237.94%   |
# Market Return : 335.70%   |   Portfolio Return : 517.96%   |
# Market Return : 335.70%   |   Portfolio Return : 895.97%   |
# Market Return : 335.70%   |   Portfolio Return : 581.84%   |
# Market Return : 335.70%   |   Portfolio Return : 875.40%   |
# Market Return : 335.70%   |   Portfolio Return : 447.07%   |
# Market Return : 335.70%   |   Portfolio Return : 1099.73%   |
# Market Return : 335.70%   |   Portfolio Return : 559.86%   |
# Market Return : 335.70%   |   Portfolio Return : 259.00%   |
# Market Return : 335.70%   |   Portfolio Return : 862.69%   |
# Market Return : 335.70%   |   Portfolio Return : 584.36%   |
# Market Return : 335.70%   |   Portfolio Return : 454.33%   |
# Market Return : 335.70%   |   Portfolio Return : 560.92%   |
# Market Return : 335.70%   |   Portfolio Return : 533.82%   |
# Market Return : 335.70%   |   Portfolio Return : 2159.30%   |
# Market Return : 335.70%   |   Portfolio Return : 705.51%   |
# Market Return : 335.70%   |   Portfolio Return : 1470.96%   |
# Market Return : 335.70%   |   Portfolio Return : 556.51%   |
# Market Return : 335.70%   |   Portfolio Return : 752.19%   |
# Market Return : 335.70%   |   Portfolio Return : 1649.64%   |
# Market Return : 335.70%   |   Portfolio Return : 513.89%   |
# Market Return : 335.70%   |   Portfolio Return : 312.28%   |
# Market Return : 335.70%   |   Portfolio Return : 575.89%   |
# Market Return : 335.70%   |   Portfolio Return : 824.17%   |
# Market Return : 335.70%   |   Portfolio Return : 798.15%   |
# Market Return : 335.70%   |   Portfolio Return : 748.09%   |
# Market Return : 335.70%   |   Portfolio Return : 252.11%   |
# Market Return : 335.70%   |   Portfolio Return : 510.59%   |
# Market Return : 335.70%   |   Portfolio Return : 860.61%   |
# Market Return : 335.70%   |   Portfolio Return : 566.39%   |
# Market Return : 335.70%   |   Portfolio Return : 681.82%   |
# Market Return : 335.70%   |   Portfolio Return : 12418.21%   |
# Market Return : 335.70%   |   Portfolio Return : 13685.93%   |
# Market Return : 335.70%   |   Portfolio Return : 9490.31%   |
# Market Return : 335.70%   |   Portfolio Return : 46731.69%   |
# Market Return : 335.70%   |   Portfolio Return : 31336.04%   |
# Market Return : 335.70%   |   Portfolio Return : 17238.70%   |
# Market Return : 335.70%   |   Portfolio Return : 15603.82%   |
# Market Return : 335.70%   |   Portfolio Return : 15540.51%   |
# Market Return : 335.70%   |   Portfolio Return : 16238.21%   |
# Market Return : 335.70%   |   Portfolio Return : 18160.05%   |
# Market Return : 335.70%   |   Portfolio Return : 47084.34%   |
# Market Return : 335.70%   |   Portfolio Return : 20072.19%   |
# Market Return : 335.70%   |   Portfolio Return : 53781.61%   |
# Market Return : 335.70%   |   Portfolio Return : 24837.35%   |
# Market Return : 335.70%   |   Portfolio Return : 77973.52%   |
# Market Return : 335.70%   |   Portfolio Return : 14624.19%   |
# Market Return : 335.70%   |   Portfolio Return : 134007.08%   |
# Market Return : 335.70%   |   Portfolio Return : 37469.59%   |
# 2024-06-24 14:34:37,447 - INFO - Episode 400/25000 - Reward: 6.251658369264659 - Epsilon: 0.9289663867799227
# Market Return : 335.70%   |   Portfolio Return : 72165.64%   |
# Market Return : 335.70%   |   Portfolio Return : 18783.73%   |
# Market Return : 335.70%   |   Portfolio Return : 51787.26%   |
# Market Return : 335.70%   |   Portfolio Return : 55682.63%   |
# Market Return : 335.70%   |   Portfolio Return : 57764.79%   |
# Market Return : 335.70%   |   Portfolio Return : 34623.57%   |
# Market Return : 335.70%   |   Portfolio Return : 45136.83%   |
# Market Return : 335.70%   |   Portfolio Return : 38865.60%   |
# Market Return : 335.70%   |   Portfolio Return : 261628.48%   |
# Market Return : 335.70%   |   Portfolio Return : 94796.59%   |
# Market Return : 335.70%   |   Portfolio Return : 57342.12%   |
# Market Return : 335.70%   |   Portfolio Return : 72152.61%   |
# Market Return : 335.70%   |   Portfolio Return : 20090.47%   |
# Market Return : 335.70%   |   Portfolio Return : 38009.87%   |
# Market Return : 335.70%   |   Portfolio Return : 172417.82%   |
# Market Return : 335.70%   |   Portfolio Return : 189104.78%   |
# Market Return : 335.70%   |   Portfolio Return : 44368.11%   |
# Market Return : 335.70%   |   Portfolio Return : 71807.43%   |
# Market Return : 335.70%   |   Portfolio Return : 60113.07%   |
# Market Return : 335.70%   |   Portfolio Return : 214484.02%   |
# Market Return : 335.70%   |   Portfolio Return : 94900.87%   |
# Market Return : 335.70%   |   Portfolio Return : 40289.91%   |
# Market Return : 335.70%   |   Portfolio Return : 49648.34%   |
# Market Return : 335.70%   |   Portfolio Return : 87532.04%   |
# Market Return : 335.70%   |   Portfolio Return : 182266.57%   |
# Market Return : 335.70%   |   Portfolio Return : 114162.03%   |
# Market Return : 335.70%   |   Portfolio Return : 783461.21%   |
# Market Return : 335.70%   |   Portfolio Return : 227645.30%   |
# Market Return : 335.70%   |   Portfolio Return : 209776.81%   |
# Market Return : 335.70%   |   Portfolio Return : 49918.06%   |
# Market Return : 335.70%   |   Portfolio Return : 278.23%   |
# Market Return : 335.70%   |   Portfolio Return : 292007.26%   |
# Market Return : 335.70%   |   Portfolio Return : 130288.13%   |
# Market Return : 335.70%   |   Portfolio Return : 106683.37%   |
# Market Return : 335.70%   |   Portfolio Return : 41.08%   |
# Market Return : 335.70%   |   Portfolio Return : 114970.53%   |
# Market Return : 335.70%   |   Portfolio Return : 69497.62%   |
# Market Return : 335.70%   |   Portfolio Return : 134516.43%   |
# Market Return : 335.70%   |   Portfolio Return : 158.09%   |
# Market Return : 335.70%   |   Portfolio Return : 231.79%   |
# Market Return : 335.70%   |   Portfolio Return : 272262.54%   |
# Market Return : 335.70%   |   Portfolio Return : 271.54%   |
# Market Return : 335.70%   |   Portfolio Return : 84462.31%   |
# Market Return : 335.70%   |   Portfolio Return : 324.82%   |
# Market Return : 335.70%   |   Portfolio Return : 155840.84%   |
# Market Return : 335.70%   |   Portfolio Return : 167008.76%   |
# Market Return : 335.70%   |   Portfolio Return : 333.65%   |
# Market Return : 335.70%   |   Portfolio Return : 213127.50%   |
# Market Return : 335.70%   |   Portfolio Return : 156835.11%   |
# Market Return : 335.70%   |   Portfolio Return : 200.22%   |
# Market Return : 335.70%   |   Portfolio Return : 145176.88%   |
# Market Return : 335.70%   |   Portfolio Return : 62909.27%   |
# Market Return : 335.70%   |   Portfolio Return : 705.85%   |
# Market Return : 335.70%   |   Portfolio Return : 241072.86%   |
# Market Return : 335.70%   |   Portfolio Return : 482.49%   |
# Market Return : 335.70%   |   Portfolio Return : 182406.53%   |
# Market Return : 335.70%   |   Portfolio Return : 365.52%   |
# Market Return : 335.70%   |   Portfolio Return : 281.45%   |
# Market Return : 335.70%   |   Portfolio Return : 429.38%   |
# Market Return : 335.70%   |   Portfolio Return : 793.18%   |
# Market Return : 335.70%   |   Portfolio Return : 373.20%   |
# Market Return : 335.70%   |   Portfolio Return : 402.46%   |
# Market Return : 335.70%   |   Portfolio Return : 457.87%   |
# Market Return : 335.70%   |   Portfolio Return : 615.90%   |
# Market Return : 335.70%   |   Portfolio Return : 599.43%   |
# Market Return : 335.70%   |   Portfolio Return : 367.34%   |
# Market Return : 335.70%   |   Portfolio Return : 1010.53%   |
# Market Return : 335.70%   |   Portfolio Return : 434.58%   |
# Market Return : 335.70%   |   Portfolio Return : 426.74%   |
# Market Return : 335.70%   |   Portfolio Return : 299.88%   |
# Market Return : 335.70%   |   Portfolio Return : 679.28%   |
# Market Return : 335.70%   |   Portfolio Return : 463.84%   |
# Market Return : 335.70%   |   Portfolio Return : 972.95%   |
# Market Return : 335.70%   |   Portfolio Return : 594.50%   |
# Market Return : 335.70%   |   Portfolio Return : 462.77%   |
# Market Return : 335.70%   |   Portfolio Return : 697.79%   |
# Market Return : 335.70%   |   Portfolio Return : 810.44%   |
# Market Return : 335.70%   |   Portfolio Return : 621.28%   |
# Market Return : 335.70%   |   Portfolio Return : 889.97%   |
# Market Return : 335.70%   |   Portfolio Return : 1188.19%   |
# Market Return : 335.70%   |   Portfolio Return : 394.70%   |
# Market Return : 335.70%   |   Portfolio Return : 607.70%   |
# Market Return : 335.70%   |   Portfolio Return : 578.77%   |
# Market Return : 335.70%   |   Portfolio Return : 459.80%   |
# Market Return : 335.70%   |   Portfolio Return : 1076.88%   |
# Market Return : 335.70%   |   Portfolio Return : 852.75%   |
# Market Return : 335.70%   |   Portfolio Return : 629.52%   |
# Market Return : 335.70%   |   Portfolio Return : 367.01%   |
# Market Return : 335.70%   |   Portfolio Return : 562.43%   |
# Market Return : 335.70%   |   Portfolio Return : 250.46%   |
# Market Return : 335.70%   |   Portfolio Return : 384.93%   |
# Market Return : 335.70%   |   Portfolio Return : 152.04%   |
# Market Return : 335.70%   |   Portfolio Return : 669.86%   |
# Market Return : 335.70%   |   Portfolio Return : 482.80%   |
# Market Return : 335.70%   |   Portfolio Return : 1918.82%   |
# Market Return : 335.70%   |   Portfolio Return : 363.27%   |
# Market Return : 335.70%   |   Portfolio Return : 377.84%   |
# Market Return : 335.70%   |   Portfolio Return : 530.12%   |
# Market Return : 335.70%   |   Portfolio Return : 1264.07%   |
# Market Return : 335.70%   |   Portfolio Return : 498.80%   |
# Market Return : 335.70%   |   Portfolio Return : 494.50%   |
# Market Return : 335.70%   |   Portfolio Return : 504.01%   |
# Market Return : 335.70%   |   Portfolio Return : 461.48%   |
# 2024-06-24 14:34:43,408 - INFO - Episode 500/25000 - Reward: 1.7254074808180127 - Epsilon: 0.9120108393558929
# Market Return : 335.70%   |   Portfolio Return : 529.51%   |
# Market Return : 335.70%   |   Portfolio Return : 216.21%   |
# Market Return : 335.70%   |   Portfolio Return : 321.53%   |
# Market Return : 335.70%   |   Portfolio Return : 325.86%   |
# Market Return : 335.70%   |   Portfolio Return : 391.03%   |
# Market Return : 335.70%   |   Portfolio Return : 377.79%   |
# Market Return : 335.70%   |   Portfolio Return : 1011.62%   |
# Market Return : 335.70%   |   Portfolio Return : 444.14%   |
# Market Return : 335.70%   |   Portfolio Return : 895.84%   |
# Market Return : 335.70%   |   Portfolio Return : 640.59%   |
# Market Return : 335.70%   |   Portfolio Return : 471.04%   |
# Market Return : 335.70%   |   Portfolio Return : 692.59%   |
# Market Return : 335.70%   |   Portfolio Return : 707.67%   |
# Market Return : 335.70%   |   Portfolio Return : 324.78%   |
# Market Return : 335.70%   |   Portfolio Return : 202.26%   |
# Market Return : 335.70%   |   Portfolio Return : 516.98%   |
# Market Return : 335.70%   |   Portfolio Return : 596.27%   |
# Market Return : 335.70%   |   Portfolio Return : 526.06%   |
# Market Return : 335.70%   |   Portfolio Return : 828.14%   |
# Market Return : 335.70%   |   Portfolio Return : 717.17%   |
# Market Return : 335.70%   |   Portfolio Return : 392.33%   |
# Market Return : 335.70%   |   Portfolio Return : 732.94%   |
# Market Return : 335.70%   |   Portfolio Return : 707.55%   |
# Market Return : 335.70%   |   Portfolio Return : 417.96%   |
# Market Return : 335.70%   |   Portfolio Return : 959.83%   |
# Market Return : 335.70%   |   Portfolio Return : 523.90%   |
# Market Return : 335.70%   |   Portfolio Return : 186.31%   |
# Market Return : 335.70%   |   Portfolio Return : 599.01%   |
# Market Return : 335.70%   |   Portfolio Return : 563.17%   |
# Market Return : 335.70%   |   Portfolio Return : 548.08%   |
# Market Return : 335.70%   |   Portfolio Return : 593.33%   |
# Market Return : 335.70%   |   Portfolio Return : 600.60%   |
# Market Return : 335.70%   |   Portfolio Return : 583.21%   |
# Market Return : 335.70%   |   Portfolio Return : 657.91%   |
# Market Return : 335.70%   |   Portfolio Return : 462.74%   |
# Market Return : 335.70%   |   Portfolio Return : 565.42%   |
# Market Return : 335.70%   |   Portfolio Return : 382.34%   |
# Market Return : 335.70%   |   Portfolio Return : 656.75%   |
# Market Return : 335.70%   |   Portfolio Return : 570.74%   |
# Market Return : 335.70%   |   Portfolio Return : 352.99%   |
# Market Return : 335.70%   |   Portfolio Return : 470.68%   |
# Market Return : 335.70%   |   Portfolio Return : 452.49%   |
# Market Return : 335.70%   |   Portfolio Return : 455.25%   |
# Market Return : 335.70%   |   Portfolio Return : 1251.41%   |
# Market Return : 335.70%   |   Portfolio Return : 617.05%   |
# Market Return : 335.70%   |   Portfolio Return : 704.46%   |
# Market Return : 335.70%   |   Portfolio Return : 821.98%   |
# Market Return : 335.70%   |   Portfolio Return : 734.00%   |
# Market Return : 335.70%   |   Portfolio Return : 326.05%   |
# Market Return : 335.70%   |   Portfolio Return : 484.67%   |
# Market Return : 335.70%   |   Portfolio Return : 730.91%   |
# Market Return : 335.70%   |   Portfolio Return : 585.14%   |
# Market Return : 335.70%   |   Portfolio Return : 359.72%   |
# Market Return : 335.70%   |   Portfolio Return : 593.34%   |
# Market Return : 335.70%   |   Portfolio Return : 484.99%   |
# Market Return : 335.70%   |   Portfolio Return : 317.11%   |
# Market Return : 335.70%   |   Portfolio Return : 224.68%   |
# Market Return : 335.70%   |   Portfolio Return : 800.23%   |
# Market Return : 335.70%   |   Portfolio Return : 539.76%   |
# Market Return : 335.70%   |   Portfolio Return : 990405.74%   |
# Market Return : 335.70%   |   Portfolio Return : 875985.89%   |
# Market Return : 335.70%   |   Portfolio Return : 411832.63%   |
# Market Return : 335.70%   |   Portfolio Return : 496965.79%   |
# Market Return : 335.70%   |   Portfolio Return : 255466.57%   |
# Market Return : 335.70%   |   Portfolio Return : 1479634.82%   |
# Market Return : 335.70%   |   Portfolio Return : 497588.71%   |
# Market Return : 335.70%   |   Portfolio Return : 647405.53%   |
# Market Return : 335.70%   |   Portfolio Return : 1119889.90%   |
# Market Return : 335.70%   |   Portfolio Return : 1125397.16%   |
# Market Return : 335.70%   |   Portfolio Return : 599017.53%   |
# Market Return : 335.70%   |   Portfolio Return : 922235.50%   |
# Market Return : 335.70%   |   Portfolio Return : 352759.18%   |
# Market Return : 335.70%   |   Portfolio Return : 1441427.57%   |
# Market Return : 335.70%   |   Portfolio Return : 865810.24%   |
# Market Return : 335.70%   |   Portfolio Return : 904116.34%   |
# Market Return : 335.70%   |   Portfolio Return : 400410.68%   |
# Market Return : 335.70%   |   Portfolio Return : 1058982.81%   |
# Market Return : 335.70%   |   Portfolio Return : 1120222.21%   |
# Market Return : 335.70%   |   Portfolio Return : 389568.46%   |
# Market Return : 335.70%   |   Portfolio Return : 472446.03%   |
# Market Return : 335.70%   |   Portfolio Return : 1206430.62%   |
# Market Return : 335.70%   |   Portfolio Return : 479992.08%   |
# Market Return : 335.70%   |   Portfolio Return : 630604.34%   |
# Market Return : 335.70%   |   Portfolio Return : 1082361.60%   |
# Market Return : 335.70%   |   Portfolio Return : 828426.52%   |
# Market Return : 335.70%   |   Portfolio Return : 1142902.12%   |
# Market Return : 335.70%   |   Portfolio Return : 758580.32%   |
# Market Return : 335.70%   |   Portfolio Return : 758823.48%   |
# Market Return : 335.70%   |   Portfolio Return : 455648.62%   |
# Market Return : 335.70%   |   Portfolio Return : 262880.67%   |
# Market Return : 335.70%   |   Portfolio Return : 156547.30%   |
# Market Return : 335.70%   |   Portfolio Return : 1089950.32%   |
# Market Return : 335.70%   |   Portfolio Return : 1224844.41%   |
# Market Return : 335.70%   |   Portfolio Return : 188070.12%   |
# Market Return : 335.70%   |   Portfolio Return : 1207397.72%   |
# Market Return : 335.70%   |   Portfolio Return : 993294.94%   |
# Market Return : 335.70%   |   Portfolio Return : 2244735.67%   |
# Market Return : 335.70%   |   Portfolio Return : 409573.19%   |
# Market Return : 335.70%   |   Portfolio Return : 1522799.81%   |
# Market Return : 335.70%   |   Portfolio Return : 907015.94%   |
# 2024-06-24 14:34:49,317 - INFO - Episode 600/25000 - Reward: 9.112855365352036 - Epsilon: 0.8953647655495741
# Market Return : 335.70%   |   Portfolio Return : 318994.31%   |
# Market Return : 335.70%   |   Portfolio Return : 522883.01%   |
# Market Return : 335.70%   |   Portfolio Return : 476801.92%   |
# Market Return : 335.70%   |   Portfolio Return : 1335034.30%   |
# Market Return : 335.70%   |   Portfolio Return : 1047642.62%   |
# Market Return : 335.70%   |   Portfolio Return : 480533.95%   |
# Market Return : 335.70%   |   Portfolio Return : 119.60%   |
# Market Return : 335.70%   |   Portfolio Return : 310.88%   |
# Market Return : 335.70%   |   Portfolio Return : 1419181.82%   |
# Market Return : 335.70%   |   Portfolio Return : 220802.42%   |
# Market Return : 335.70%   |   Portfolio Return : 98.77%   |
# Market Return : 335.70%   |   Portfolio Return : 58.90%   |
# Market Return : 335.70%   |   Portfolio Return : 158.00%   |
# Market Return : 335.70%   |   Portfolio Return : 202.07%   |
# Market Return : 335.70%   |   Portfolio Return : 435.31%   |
# Market Return : 335.70%   |   Portfolio Return : 1406955.15%   |
# Market Return : 335.70%   |   Portfolio Return : 61.62%   |
# Market Return : 335.70%   |   Portfolio Return : 306.24%   |
# Market Return : 335.70%   |   Portfolio Return : 162.98%   |
# Market Return : 335.70%   |   Portfolio Return : 221.81%   |
# Market Return : 335.70%   |   Portfolio Return : 1500423.73%   |
# Market Return : 335.70%   |   Portfolio Return : 187.12%   |
# Market Return : 335.70%   |   Portfolio Return : 822066.48%   |
# Market Return : 335.70%   |   Portfolio Return : 243.96%   |
# Market Return : 335.70%   |   Portfolio Return : 354.97%   |
# Market Return : 335.70%   |   Portfolio Return : 298.75%   |
# Market Return : 335.70%   |   Portfolio Return : 482180.98%   |
# Market Return : 335.70%   |   Portfolio Return : 365.32%   |
# Market Return : 335.70%   |   Portfolio Return : 356.15%   |
# Market Return : 335.70%   |   Portfolio Return : 330.22%   |
# Market Return : 335.70%   |   Portfolio Return : 599.01%   |
# Market Return : 335.70%   |   Portfolio Return : 1045.20%   |
# Market Return : 335.70%   |   Portfolio Return : 431.08%   |
# Market Return : 335.70%   |   Portfolio Return : 603.55%   |
# Market Return : 335.70%   |   Portfolio Return : 616.16%   |
# Market Return : 335.70%   |   Portfolio Return : 457.12%   |
# Market Return : 335.70%   |   Portfolio Return : 559.20%   |
# Market Return : 335.70%   |   Portfolio Return : 445.95%   |
# Market Return : 335.70%   |   Portfolio Return : 594.09%   |
# Market Return : 335.70%   |   Portfolio Return : 531.02%   |
# Market Return : 335.70%   |   Portfolio Return : 695.71%   |
# Market Return : 335.70%   |   Portfolio Return : 450.58%   |
# Market Return : 335.70%   |   Portfolio Return : 286.50%   |
# Market Return : 335.70%   |   Portfolio Return : 676.84%   |
# Market Return : 335.70%   |   Portfolio Return : 446.50%   |
# Market Return : 335.70%   |   Portfolio Return : 439.83%   |
# Market Return : 335.70%   |   Portfolio Return : 409.83%   |
# Market Return : 335.70%   |   Portfolio Return : 385.75%   |
# Market Return : 335.70%   |   Portfolio Return : 455.54%   |
# Market Return : 335.70%   |   Portfolio Return : 474.12%   |
# Market Return : 335.70%   |   Portfolio Return : 347.48%   |
# Market Return : 335.70%   |   Portfolio Return : 280.97%   |
# Market Return : 335.70%   |   Portfolio Return : 586.71%   |
# Market Return : 335.70%   |   Portfolio Return : 430.14%   |
# Market Return : 335.70%   |   Portfolio Return : 418.05%   |
# Market Return : 335.70%   |   Portfolio Return : 654.89%   |
# Market Return : 335.70%   |   Portfolio Return : 550.29%   |
# Market Return : 335.70%   |   Portfolio Return : 515.16%   |
# Market Return : 335.70%   |   Portfolio Return : 362.67%   |
# Market Return : 335.70%   |   Portfolio Return : 276.10%   |
# Market Return : 335.70%   |   Portfolio Return : 431.57%   |
# Market Return : 335.70%   |   Portfolio Return : 208.29%   |
# Market Return : 335.70%   |   Portfolio Return : 617.62%   |
# Market Return : 335.70%   |   Portfolio Return : 313.46%   |
# Market Return : 335.70%   |   Portfolio Return : 290.20%   |
# Market Return : 335.70%   |   Portfolio Return : 872.91%   |
# Market Return : 335.70%   |   Portfolio Return : 433.56%   |
# Market Return : 335.70%   |   Portfolio Return : 422.11%   |
# Market Return : 335.70%   |   Portfolio Return : 493.16%   |
# Market Return : 335.70%   |   Portfolio Return : 662.83%   |
# Market Return : 335.70%   |   Portfolio Return : 598.53%   |
# Market Return : 335.70%   |   Portfolio Return : 343.68%   |
# Market Return : 335.70%   |   Portfolio Return : 557.80%   |
# Market Return : 335.70%   |   Portfolio Return : 338.33%   |
# Market Return : 335.70%   |   Portfolio Return : 552.97%   |
# Market Return : 335.70%   |   Portfolio Return : 618.80%   |
# Market Return : 335.70%   |   Portfolio Return : 423.50%   |
# Market Return : 335.70%   |   Portfolio Return : 274.85%   |
# Market Return : 335.70%   |   Portfolio Return : 723.13%   |
# Market Return : 335.70%   |   Portfolio Return : 455.21%   |
# Market Return : 335.70%   |   Portfolio Return : 331.61%   |
# Market Return : 335.70%   |   Portfolio Return : 415.98%   |
# Market Return : 335.70%   |   Portfolio Return : 317.15%   |
# Market Return : 335.70%   |   Portfolio Return : 379.42%   |
# Market Return : 335.70%   |   Portfolio Return : 450.00%   |
# Market Return : 335.70%   |   Portfolio Return : 286.97%   |
# Market Return : 335.70%   |   Portfolio Return : 468.62%   |
# Market Return : 335.70%   |   Portfolio Return : 374.11%   |
# Market Return : 335.70%   |   Portfolio Return : 367.75%   |
# Market Return : 335.70%   |   Portfolio Return : 428.77%   |
# Market Return : 335.70%   |   Portfolio Return : 304.14%   |
# Market Return : 335.70%   |   Portfolio Return : 443.19%   |
# Market Return : 335.70%   |   Portfolio Return : 782.05%   |
# Market Return : 335.70%   |   Portfolio Return : 418.10%   |
# Market Return : 335.70%   |   Portfolio Return : 395.48%   |
# Market Return : 335.70%   |   Portfolio Return : 453.22%   |
# Market Return : 335.70%   |   Portfolio Return : 416.10%   |
# 2024-06-24 14:34:55,268 - INFO - Episode 700/25000 - Reward: 9.658600679640852 - Epsilon: 0.8790225168308622
# Market Return : 335.70%   |   Portfolio Return : 329.17%   |
# ...
# Market Return : 335.70%   |   Portfolio Return : 190305.66%   |
# Market Return : 335.70%   |   Portfolio Return : 156375.33%   |
# Market Return : 335.70%   |   Portfolio Return : 2102563.96%   |
# Market Return : 335.70%   |   Portfolio Return : 75025.78%   |
# Market Return : 335.70%   |   Portfolio Return : 52719.18%   |
# Market Return : 335.70%   |   Portfolio Return : 129212.48%   |
# Market Return : 335.70%   |   Portfolio Return : 162538.66%   |
# Market Return : 335.70%   |   Portfolio Return : 173633.98%   |
# Market Return : 335.70%   |   Portfolio Return : 181124.24%   |
# Market Return : 335.70%   |   Portfolio Return : 182732.15%   |
# Market Return : 335.70%   |   Portfolio Return : 182385.28%   |
# Market Return : 335.70%   |   Portfolio Return : 173290.06%   |
# Market Return : 335.70%   |   Portfolio Return : 3522673.97%   |
# Market Return : 335.70%   |   Portfolio Return : 3024604.03%   |
# Market Return : 335.70%   |   Portfolio Return : 245195.83%   |
# Market Return : 335.70%   |   Portfolio Return : 3239364.63%   |
# Market Return : 335.70%   |   Portfolio Return : 3489080.71%   |
# Market Return : 335.70%   |   Portfolio Return : 2929479.47%   |
# Market Return : 335.70%   |   Portfolio Return : 472.56%   |
# Market Return : 335.70%   |   Portfolio Return : 320.05%   |
# Market Return : 335.70%   |   Portfolio Return : 665.12%   |
# Market Return : 335.70%   |   Portfolio Return : 418.99%   |
# Market Return : 335.70%   |   Portfolio Return : 335.97%   |
# Market Return : 335.70%   |   Portfolio Return : 433.27%   |
# Market Return : 335.70%   |   Portfolio Return : 455.67%   |
# Market Return : 335.70%   |   Portfolio Return : 465.51%   |
# Market Return : 335.70%   |   Portfolio Return : 437.98%   |
# Market Return : 335.70%   |   Portfolio Return : 155.32%   |
# Market Return : 335.70%   |   Portfolio Return : 510.27%   |
# Market Return : 335.70%   |   Portfolio Return : 501.26%   |
# Market Return : 335.70%   |   Portfolio Return : 446.96%   |
# Market Return : 335.70%   |   Portfolio Return : 515.48%   |
# Market Return : 335.70%   |   Portfolio Return : 456.91%   |
# Market Return : 335.70%   |   Portfolio Return : 360.69%   |
# Market Return : 335.70%   |   Portfolio Return : 273.82%   |
# Market Return : 335.70%   |   Portfolio Return : 330.70%   |
# 2024-06-24 14:40:16,273 - INFO - Episode 6000/25000 - Reward: 1.774744511794722 - Epsilon: 0.3311311214825243
# Market Return : 335.70%   |   Portfolio Return : 524.34%   |
# Market Return : 335.70%   |   Portfolio Return : 371.06%   |
# Market Return : 335.70%   |   Portfolio Return : 595.37%   |
# Market Return : 335.70%   |   Portfolio Return : 489.88%   |
# Market Return : 335.70%   |   Portfolio Return : 397.17%   |
# Market Return : 335.70%   |   Portfolio Return : 330.79%   |
# Market Return : 335.70%   |   Portfolio Return : 350.95%   |
# Market Return : 335.70%   |   Portfolio Return : 442.42%   |
# Market Return : 335.70%   |   Portfolio Return : 409.28%   |
# Market Return : 335.70%   |   Portfolio Return : 261.05%   |
# Market Return : 335.70%   |   Portfolio Return : 364.90%   |
# Market Return : 335.70%   |   Portfolio Return : 419.33%   |
# Market Return : 335.70%   |   Portfolio Return : 310.01%   |
# Market Return : 335.70%   |   Portfolio Return : 410.01%   |
# Market Return : 335.70%   |   Portfolio Return : 485.41%   |
# Market Return : 335.70%   |   Portfolio Return : 393.23%   |
# Market Return : 335.70%   |   Portfolio Return : 323.95%   |
# Market Return : 335.70%   |   Portfolio Return : 370.51%   |
# Market Return : 335.70%   |   Portfolio Return : 389.65%   |
# Market Return : 335.70%   |   Portfolio Return : 365.06%   |
# Market Return : 335.70%   |   Portfolio Return : 411.62%   |
# Market Return : 335.70%   |   Portfolio Return : 482.59%   |
# Market Return : 335.70%   |   Portfolio Return : 272.92%   |
# Market Return : 335.70%   |   Portfolio Return : 459.88%   |
# Market Return : 335.70%   |   Portfolio Return : 597.92%   |
# Market Return : 335.70%   |   Portfolio Return : 483.45%   |
# Market Return : 335.70%   |   Portfolio Return : 362.99%   |
# Market Return : 335.70%   |   Portfolio Return : 559.20%   |
# Market Return : 335.70%   |   Portfolio Return : 357.35%   |
# Market Return : 335.70%   |   Portfolio Return : 353.04%   |
# Market Return : 335.70%   |   Portfolio Return : 475.57%   |
# Market Return : 335.70%   |   Portfolio Return : 468.07%   |
# Market Return : 335.70%   |   Portfolio Return : 597.88%   |
# Market Return : 335.70%   |   Portfolio Return : 466.28%   |
# Market Return : 335.70%   |   Portfolio Return : 489.09%   |
# Market Return : 335.70%   |   Portfolio Return : 347.50%   |
# Market Return : 335.70%   |   Portfolio Return : 474.39%   |
# Market Return : 335.70%   |   Portfolio Return : 408.28%   |
# Market Return : 335.70%   |   Portfolio Return : 419.04%   |
# Market Return : 335.70%   |   Portfolio Return : 556.10%   |
# Market Return : 335.70%   |   Portfolio Return : 259.91%   |
# Market Return : 335.70%   |   Portfolio Return : 475.27%   |
# Market Return : 335.70%   |   Portfolio Return : 315.72%   |
# Market Return : 335.70%   |   Portfolio Return : 304.44%   |
# Market Return : 335.70%   |   Portfolio Return : 361.13%   |
# Market Return : 335.70%   |   Portfolio Return : 291.24%   |
# Market Return : 335.70%   |   Portfolio Return : 397.58%   |
# Market Return : 335.70%   |   Portfolio Return : 455.56%   |
# Market Return : 335.70%   |   Portfolio Return : 553.49%   |
# Market Return : 335.70%   |   Portfolio Return : 486.25%   |
# Market Return : 335.70%   |   Portfolio Return : 312.80%   |
# Market Return : 335.70%   |   Portfolio Return : 395.55%   |
# Market Return : 335.70%   |   Portfolio Return : 576.71%   |
# Market Return : 335.70%   |   Portfolio Return : 359.89%   |
# Market Return : 335.70%   |   Portfolio Return : 380.74%   |
# Market Return : 335.70%   |   Portfolio Return : 3682356.64%   |
# Market Return : 335.70%   |   Portfolio Return : 3498729.79%   |
# Market Return : 335.70%   |   Portfolio Return : 3275654.11%   |
# Market Return : 335.70%   |   Portfolio Return : 3424744.26%   |
# Market Return : 335.70%   |   Portfolio Return : 3165552.77%   |
# Market Return : 335.70%   |   Portfolio Return : 3076476.70%   |
# Market Return : 335.70%   |   Portfolio Return : 3426208.79%   |
# Market Return : 335.70%   |   Portfolio Return : 3425853.41%   |
# Market Return : 335.70%   |   Portfolio Return : 3133272.51%   |
# Market Return : 335.70%   |   Portfolio Return : 3129132.83%   |
# Market Return : 335.70%   |   Portfolio Return : 3160578.80%   |
# Market Return : 335.70%   |   Portfolio Return : 3129056.70%   |
# Market Return : 335.70%   |   Portfolio Return : 3096098.09%   |
# Market Return : 335.70%   |   Portfolio Return : 2731811.90%   |
# Market Return : 335.70%   |   Portfolio Return : 3595942.45%   |
# Market Return : 335.70%   |   Portfolio Return : 2883422.71%   |
# Market Return : 335.70%   |   Portfolio Return : 3266366.11%   |
# Market Return : 335.70%   |   Portfolio Return : 2881160.64%   |
# Market Return : 335.70%   |   Portfolio Return : 3905118.36%   |
# Market Return : 335.70%   |   Portfolio Return : 3275496.23%   |
# Market Return : 335.70%   |   Portfolio Return : 3131269.59%   |
# Market Return : 335.70%   |   Portfolio Return : 3085538.57%   |
# Market Return : 335.70%   |   Portfolio Return : 3522569.12%   |
# Market Return : 335.70%   |   Portfolio Return : 3957248.52%   |
# Market Return : 335.70%   |   Portfolio Return : 2921869.95%   |
# Market Return : 335.70%   |   Portfolio Return : 3424933.32%   |
# Market Return : 335.70%   |   Portfolio Return : 204759.12%   |
# Market Return : 335.70%   |   Portfolio Return : 112106.55%   |
# Market Return : 335.70%   |   Portfolio Return : 174179.70%   |
# Market Return : 335.70%   |   Portfolio Return : 215996.69%   |
# Market Return : 335.70%   |   Portfolio Return : 177382.26%   |
# Market Return : 335.70%   |   Portfolio Return : 165354.76%   |
# Market Return : 335.70%   |   Portfolio Return : 49.80%   |
# Market Return : 335.70%   |   Portfolio Return : 219125.31%   |
# Market Return : 335.70%   |   Portfolio Return : 92960.93%   |
# Market Return : 335.70%   |   Portfolio Return : 183773.90%   |
# Market Return : 335.70%   |   Portfolio Return :  4.99%   |
# Market Return : 335.70%   |   Portfolio Return : 168231.91%   |
# Market Return : 335.70%   |   Portfolio Return : 228970.93%   |
# Market Return : 335.70%   |   Portfolio Return : 15.34%   |
# Market Return : 335.70%   |   Portfolio Return : 181461.80%   |
# Market Return : 335.70%   |   Portfolio Return : 18.70%   |
# Market Return : 335.70%   |   Portfolio Return : 95527.31%   |
# Market Return : 335.70%   |   Portfolio Return : 206080.39%   |
# Market Return : 335.70%   |   Portfolio Return : 160442.92%   |
# Market Return : 335.70%   |   Portfolio Return : 58660.56%   |
# 2024-06-24 14:40:22,217 - INFO - Episode 6100/25000 - Reward: 7.2744161106038625 - Epsilon: 0.3250872973853678
# Market Return : 335.70%   |   Portfolio Return : 152916.85%   |
# Market Return : 335.70%   |   Portfolio Return : 29.28%   |
# Market Return : 335.70%   |   Portfolio Return : 144190.84%   |
# Market Return : 335.70%   |   Portfolio Return : 221246.98%   |
# Market Return : 335.70%   |   Portfolio Return : 222078.74%   |
# Market Return : 335.70%   |   Portfolio Return :  4.61%   |
# Market Return : 335.70%   |   Portfolio Return : 166361.14%   |
# Market Return : 335.70%   |   Portfolio Return : 180023.95%   |
# Market Return : 335.70%   |   Portfolio Return : 184495.09%   |
# Market Return : 335.70%   |   Portfolio Return : 170961.72%   |
# Market Return : 335.70%   |   Portfolio Return :  5.01%   |
# Market Return : 335.70%   |   Portfolio Return : 178402.42%   |
# Market Return : 335.70%   |   Portfolio Return : 38.66%   |
# Market Return : 335.70%   |   Portfolio Return : 166379.13%   |
# Market Return : 335.70%   |   Portfolio Return : 153637.39%   |
# Market Return : 335.70%   |   Portfolio Return : 3933245.02%   |
# Market Return : 335.70%   |   Portfolio Return : 3184728.00%   |
# Market Return : 335.70%   |   Portfolio Return : 187334.04%   |
# Market Return : 335.70%   |   Portfolio Return :  4.98%   |
# Market Return : 335.70%   |   Portfolio Return : 178795.88%   |
# Market Return : 335.70%   |   Portfolio Return : 23.54%   |
# Market Return : 335.70%   |   Portfolio Return : 218570.65%   |
# Market Return : 335.70%   |   Portfolio Return : 1607.23%   |
# Market Return : 335.70%   |   Portfolio Return : 2471805.12%   |
# Market Return : 335.70%   |   Portfolio Return : 193.97%   |
# Market Return : 335.70%   |   Portfolio Return : 154.21%   |
# Market Return : 335.70%   |   Portfolio Return : 149.81%   |
# Market Return : 335.70%   |   Portfolio Return : 198.67%   |
# Market Return : 335.70%   |   Portfolio Return : 2399419.58%   |
# Market Return : 335.70%   |   Portfolio Return : 76.59%   |
# Market Return : 335.70%   |   Portfolio Return : 271.66%   |
# Market Return : 335.70%   |   Portfolio Return : 2874217.51%   |
# Market Return : 335.70%   |   Portfolio Return : 2772622.48%   |
# Market Return : 335.70%   |   Portfolio Return : 2767550.07%   |
# Market Return : 335.70%   |   Portfolio Return : 2903657.75%   |
# Market Return : 335.70%   |   Portfolio Return : 2494516.32%   |
# Market Return : 335.70%   |   Portfolio Return : 3093499.76%   |
# Market Return : 335.70%   |   Portfolio Return : 1889130.31%   |
# Market Return : 335.70%   |   Portfolio Return : 155.72%   |
# Market Return : 335.70%   |   Portfolio Return : 3681911.08%   |
# Market Return : 335.70%   |   Portfolio Return : 2290630.77%   |
# Market Return : 335.70%   |   Portfolio Return : 2914679.20%   |
# Market Return : 335.70%   |   Portfolio Return : 253.10%   |
# Market Return : 335.70%   |   Portfolio Return : 230.87%   |
# Market Return : 335.70%   |   Portfolio Return : 2295344.69%   |
# Market Return : 335.70%   |   Portfolio Return : 31.58%   |
# Market Return : 335.70%   |   Portfolio Return : 21.32%   |
# Market Return : 335.70%   |   Portfolio Return : 231.32%   |
# Market Return : 335.70%   |   Portfolio Return : 2500862.23%   |
# Market Return : 335.70%   |   Portfolio Return : 1953347.61%   |
# Market Return : 335.70%   |   Portfolio Return : 2220589.18%   |
# Market Return : 335.70%   |   Portfolio Return : 1842125.83%   |
# Market Return : 335.70%   |   Portfolio Return : 2783714.58%   |
# Market Return : 335.70%   |   Portfolio Return : 361.07%   |
# Market Return : 335.70%   |   Portfolio Return : 375.19%   |
# Market Return : 335.70%   |   Portfolio Return : 325.37%   |
# Market Return : 335.70%   |   Portfolio Return : 301.40%   |
# Market Return : 335.70%   |   Portfolio Return : 366.61%   |
# Market Return : 335.70%   |   Portfolio Return : 346.93%   |
# Market Return : 335.70%   |   Portfolio Return : 321.68%   |
# Market Return : 335.70%   |   Portfolio Return : 327.47%   |
# Market Return : 335.70%   |   Portfolio Return : 330.09%   |
# Market Return : 335.70%   |   Portfolio Return : 440.14%   |
# Market Return : 335.70%   |   Portfolio Return : 352.62%   |
# Market Return : 335.70%   |   Portfolio Return : 355.67%   |
# Market Return : 335.70%   |   Portfolio Return : 366.28%   |
# Market Return : 335.70%   |   Portfolio Return : 361.34%   |
# Market Return : 335.70%   |   Portfolio Return : 407.43%   |
# Market Return : 335.70%   |   Portfolio Return : 339.08%   |
# Market Return : 335.70%   |   Portfolio Return : 310.21%   |
# Market Return : 335.70%   |   Portfolio Return : 359.17%   |
# Market Return : 335.70%   |   Portfolio Return : 390.41%   |
# Market Return : 335.70%   |   Portfolio Return : 394.54%   |
# Market Return : 335.70%   |   Portfolio Return : 357.24%   |
# Market Return : 335.70%   |   Portfolio Return : 383.08%   |
# Market Return : 335.70%   |   Portfolio Return : 411.65%   |
# Market Return : 335.70%   |   Portfolio Return : 270.51%   |
# Market Return : 335.70%   |   Portfolio Return : 295.87%   |
# Market Return : 335.70%   |   Portfolio Return : 367.23%   |
# Market Return : 335.70%   |   Portfolio Return : 417.40%   |
# Market Return : 335.70%   |   Portfolio Return : 308.62%   |
# Market Return : 335.70%   |   Portfolio Return : 343.22%   |
# Market Return : 335.70%   |   Portfolio Return : 326.18%   |
# Market Return : 335.70%   |   Portfolio Return : 375.32%   |
# Market Return : 335.70%   |   Portfolio Return : 344.51%   |
# Market Return : 335.70%   |   Portfolio Return : 409.83%   |
# Market Return : 335.70%   |   Portfolio Return : 293.30%   |
# Market Return : 335.70%   |   Portfolio Return : 610.77%   |
# Market Return : 335.70%   |   Portfolio Return : 451.59%   |
# Market Return : 335.70%   |   Portfolio Return : 420.75%   |
# Market Return : 335.70%   |   Portfolio Return : 365.27%   |
# Market Return : 335.70%   |   Portfolio Return : 347.56%   |
# Market Return : 335.70%   |   Portfolio Return : 299.75%   |
# Market Return : 335.70%   |   Portfolio Return : 467.54%   |
# Market Return : 335.70%   |   Portfolio Return : 493.34%   |
# Market Return : 335.70%   |   Portfolio Return : 333.32%   |
# Market Return : 335.70%   |   Portfolio Return : 347.53%   |
# Market Return : 335.70%   |   Portfolio Return : 290.64%   |
# Market Return : 335.70%   |   Portfolio Return : 439.03%   |
# Market Return : 335.70%   |   Portfolio Return : 258.76%   |
# Market Return : 335.70%   |   Portfolio Return : 360.97%   |
# Market Return : 335.70%   |   Portfolio Return : 345.21%   |
# 2024-06-24 14:40:28,211 - INFO - Episode 6200/25000 - Reward: 1.6144243817072217 - Epsilon: 0.3191537855100098

# %%
def plot_grid(env, agent, reward_across_episodes: list, epsilons_across_episodes: list) -> None:
    env.train = False
    total_reward_learned_policy = [run_learned_policy(env, agent) for _ in range(30)]

    plt.figure(figsize=(15, 10))

    # Main plot
    plt.subplot(2, 2, 1)
    plt.plot(reward_across_episodes, 'ro')
    plt.xlabel('Episode')
    plt.ylabel('Reward Value')
    plt.title('Rewards Per Episode (Training)')
    plt.grid()

    plt.subplot(2, 2, 2)
    plt.plot(total_reward_learned_policy, 'ro')
    plt.xlabel('Episode')
    plt.ylabel('Reward Value')
    plt.title('Rewards Per Episode (Learned Policy Evaluation)')
    plt.grid()

    # Extra plots
    plt.subplot(2, 2, 3)
    plt.plot(reward_across_episodes)
    plt.xlabel('Episode')
    plt.ylabel('Cumulative Reward Per Episode (Training)')
    plt.title('Cumulative Reward vs Episode')
    plt.grid()

    plt.subplot(2, 2, 4)
    plt.plot(epsilons_across_episodes)
    plt.xlabel('Episode')
    plt.ylabel('Epsilon Values')
    plt.title('Epsilon Decay')
    plt.grid()

    plt.tight_layout()
    plt.show()

plot_grid(env, agent, reward_across_episodes, epsilons_across_episodes)

# %%
stock_trading_environment = StockTradingEnvironment('./AAPL_data.csv', number_of_days_to_consider=30)
stock_trading_environment.train = False
obs, _ = stock_trading_environment.reset()
terminated, truncated = False, False
while not terminated:
    # Convert observation to a tuple
    obs_tuple = tuple(obs.flatten())
    action = np.argmax(agent.q_table1.get(obs_tuple, np.zeros(env.action_space.n)) + agent.q_table2.get(obs_tuple, np.zeros(env.action_space.n)))
    obs, reward, terminated, truncated, info = stock_trading_environment.step(action)

stock_trading_environment.render()

# %%
save_pickle(agent, 'aapl_q_learning_agent.pkl')

# %% [markdown]
# #### Forecast

# %%
agent = load_pickle("aapl_q_learning_agent.pkl")

# %%
stock_trading_environment = StockTradingEnvironment('./AAPL_data.csv', number_of_days_to_consider=30)
stock_trading_environment.train = False
obs, _ = stock_trading_environment.reset()
terminated, truncated = False, False
while not terminated:
    # Convert observation to a tuple
    obs_tuple = tuple(obs.flatten())
    action = np.argmax(agent.q_table1.get(obs_tuple, np.zeros(env.action_space.n)) + agent.q_table2.get(obs_tuple, np.zeros(env.action_space.n)))
    obs, reward, terminated, truncated, info = stock_trading_environment.step(action)

stock_trading_environment.render()
